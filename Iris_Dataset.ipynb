# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuj2615/Anuj2615/blob/main/Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
#import IRIS DATASET
iris = load_iris()
df=pd.read_csv('/content/drive/MyDrive/Projects/DataSet/Iris.csv')
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target

# %%
#print all data from dataset is two type::::::::::::::::::::::::::::::::::::::::
print(df)
print(df.info)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print(df.tail(10))
print(df.columns)
print(df.dtypes)
print(df.describe())
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 140        2
# 141        2
# 142        2
# 143        2
# 144        2
# 145        2
# ...

# %%
print(df.isnull().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
df['species'] = df['species'].map({
    0: 'setosa',
    1: 'versicolor',
    2: 'virginica'
})

# %%
#pie plot
plt.plot(df['sepal length (cm)'])
plt.title("Sepal Length Line Plot")
plt.xlabel("Index")
plt.ylabel("Sepal Length")
plt.show()

# %%
#Histogram
plt.hist(df['petal length (cm)'], bins=20)
plt.title("Petal Length Distribution")
plt.ylabel("Frequency")
df.iloc[:,:-1].hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

# %%
#ScatterPlot
plt.scatter(df['sepal length (cm)'], df['petal length (cm)'])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal vs Petal Length")
plt.show()

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
sns.boxplot(x='species', y='petal length (cm)', data=df)
plt.show()
